# %% [markdown]
# ## Deteksi Malaria cell menggunakan Convolutional Neural Network

# %% [markdown]
# ### Steps to solve the problem :-
#    1. Importing Libraries.
#    2. Loading the data.
#    3. Data preprocessing.
#    4. Data augmentation.
#    5. Ploting images and its labels to understand how does an infected cell and uninfected cell looks like.
#    6. Spliting data in Train , Evaluation and Test set.
#    7. Creating a Convolution Neural Network function.
#    8. Wrapping it with Tensorflow Estimator function.
#    9. Training the data on Train data.
#    10. Evaluating on evaluation data.
#    11. Predicting on Test data
#    12. Ploting the predicted image and its respective True value and predicted value.

# %% [markdown]
# 1. Masukkan Libraries

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.8)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (0.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2020.6.20)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.0.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.3)

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-4aaa7173-adde-470b-bb5a-1ea11cb87dab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4aaa7173-adde-470b-bb5a-1ea11cb87dab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"xosyasalassa","key":"ee817cad82445813c8cc05e7fb738509"}'}

# %%
#before importing the dataset we want to use this code
# The Kaggle API client expects this file to be in ~/.kaggle,
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d iarunava/cell-images-for-detecting-malaria
# Out:
# Downloading cell-images-for-detecting-malaria.zip to /content
#  97% 657M/675M [00:04<00:00, 193MB/s]
# 100% 675M/675M [00:04<00:00, 169MB/s]

# %%
# !unzip "/content/cell_images.zip" -d "/content/cell_images"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_118.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_126.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_134.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_141.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_168.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_175.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_183.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_221.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_222.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_87.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_91.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_104.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_13.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_146.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_168.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_177.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_179.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_186.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_20.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_219.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_236.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_251.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_254.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_33.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_58.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_111.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_134.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_160.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_164.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_169.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_171.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_18.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_180.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_187.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_199.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_208.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_32.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_48.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_89.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_127.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_143.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_196.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_206.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_209.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_253.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_254.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_26.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_46.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_8.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_84.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_88.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_110.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_126.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_152.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_16.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_167.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_168.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_169.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_178.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_18.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_184.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_4.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_43.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_67.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_88.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_12.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_129.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_138.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_154.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_158.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_17.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_199.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_222.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_244.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_245.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_56.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_63.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_72.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_99.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_11.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_119.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_128.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_146.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_162.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_200.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_225.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_25.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_38.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_40.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_45.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_54.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_76.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_80.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_11.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_120.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_131.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_148.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_151.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_165.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_220.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_235.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_259.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_38.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_47.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_67.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_93.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_100.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_103.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_105.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_153.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_172.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_18.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_228.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_24.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_259.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_35.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_38.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_73.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_96.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114038_cell_106.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114038_cell_109.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114038_cell_120.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114038_cell_139.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114038_cell_170.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114038_cell_192.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114038_cell_201.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114038_cell_36.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114038_cell_84.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114038_cell_97.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114345_cell_103.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114345_cell_115.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114345_cell_164.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114345_cell_179.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114345_cell_189.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114345_cell_30.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114345_cell_46.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114345_cell_55.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114345_cell_59.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114345_cell_84.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114444_cell_127.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114444_cell_133.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114444_cell_141.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114444_cell_159.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114444_cell_28.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114444_cell_32.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114444_cell_41.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114444_cell_65.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114444_cell_90.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114444_cell_91.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114605_cell_123.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114605_cell_151.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114605_cell_163.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114605_cell_164.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114605_cell_171.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114605_cell_18.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114605_cell_24.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114605_cell_64.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114605_cell_75.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114605_cell_83.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114653_cell_106.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114653_cell_120.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114653_cell_125.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114653_cell_126.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114653_cell_13.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114653_cell_133.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114653_cell_148.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114653_cell_154.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114653_cell_58.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114653_cell_95.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114914_cell_165.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114914_cell_174.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114914_cell_180.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114914_cell_190.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114914_cell_26.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114914_cell_36.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114914_cell_40.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114914_cell_42.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114914_cell_51.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_114914_cell_91.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_115017_cell_115.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_115017_cell_148.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_115017_cell_172.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_115017_cell_184.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_115017_cell_187.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_115017_cell_188.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_115017_cell_191.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_115017_cell_25.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_115017_cell_41.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C238NThinF_IMG_20151207_115017_cell_95.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_1.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_127.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_146.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_154.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_162.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_174.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_202.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_215.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_216.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_279.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_39.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_60.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_71.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_76.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_128.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_130.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_17.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_174.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_178.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_181.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_196.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_225.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_24.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_262.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_3.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_54.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_71.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_82.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_12.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_164.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_199.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_216.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_237.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_244.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_250.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_26.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_265.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_273.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_291.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_62.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_91.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_116.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_117.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_123.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_132.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_173.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_23.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_236.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_237.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_245.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_284.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_38.png
#   inflating: /content/cell_images/cell_images/cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell
        resize_img = image_array.resize((50 , 50))
        rotated45 = resize_img.rotate(45)
        rotated75 = resize_img.rotate(75)
        blur = cv2.blur(np.array(resize_img) ,(10,10))
        data.append(np.array(resize_img))
        data.append(np.array(rotated45))
        data.append(np.array(rotated75))
        data.append(np.array(blur))
        labels.append(1)
        labels.append(1)
        labels.append(1)
        labels.append(1)
        
    except AttributeError:
        print('')
        
for u in uninfected:
    try:
        
        image = cv2.imread("/content/cell_images/Uninfected/"+u)
        image_array = Image.fromarray(image , 'RGB')
        resize_img = image_array.resize((50 , 50))
        rotated45 = resize_img.rotate(45)
        rotated75 = resize_img.rotate(75)
        data.append(np.array(resize_img))
        data.append(np.array(rotated45))
        data.append(np.array(rotated75))
        labels.append(0)
        labels.append(0)
        labels.append(0)
        
    except AttributeError:
        print('')

# %% [markdown]
# 4. Data Augmentation

# %%
cells = np.array(data)
labels = np.array(labels)

np.save('Cells' , cells)
np.save('Labels' , labels)

# %%
print('Cells : {} | labels : {}'.format(cells.shape , labels.shape))
# Out:
# Cells : (96453, 50, 50, 3) | labels : (96453,)

# %% [markdown]
# 5. Ploting images and its labels to understand how does an infected cell and uninfected cell looks like.

# %%
plt.figure(1 , figsize = (15 , 9))
n = 0 
for i in range(49):
    n += 1 
    r = np.random.randint(0 , cells.shape[0] , 1)
    plt.subplot(7 , 7 , n)
    plt.subplots_adjust(hspace = 0.5 , wspace = 0.5)
    plt.imshow(cells[r[0]])
    plt.title('{} : {}'.format('Infected' if labels[r[0]] == 1 else 'Unifected' ,
                               labels[r[0]]) )
    plt.xticks([]) , plt.yticks([])
    
plt.show()

# %%
plt.figure(1, figsize = (15 , 7))
plt.subplot(1 , 2 , 1)
plt.imshow(cells[0])
plt.title('Infected Cell')
plt.xticks([]) , plt.yticks([])

plt.subplot(1 , 2 , 2)
plt.imshow(cells[20000])
plt.title('Uninfected Cell')
plt.xticks([]) , plt.yticks([])

plt.show()

# %%
n = np.arange(cells.shape[0])
np.random.shuffle(n)
cells = cells[n]
labels = labels[n]

# %%
cells = cells.astype(np.float32)
labels = labels.astype(np.int32)
cells = cells/255

# %% [markdown]
# 6. Spliting data in Train , Evaluation and Test set.

# %%
from sklearn.model_selection import train_test_split

train_x , x , train_y , y = train_test_split(cells , labels , 
                                            test_size = 0.2 ,
                                            random_state = 111)

eval_x , test_x , eval_y , test_y = train_test_split(x , y , 
                                                    test_size = 0.5 , 
                                                    random_state = 111)

# %%
plt.figure(1 , figsize = (15 ,5))
n = 0 
for z , j in zip([train_y , eval_y , test_y] , ['train labels','eval labels','test labels']):
    n += 1
    plt.subplot(1 , 3  , n)
    sns.countplot(x = z )
    plt.title(j)
plt.show()

# %%
print('train data shape {} ,eval data shape {} , test data shape {}'.format(train_x.shape,
                                                                           eval_x.shape ,
                                                                           test_x.shape))
# Out:
# train data shape (77162, 50, 50, 3) ,eval data shape (9645, 50, 50, 3) , test data shape (9646, 50, 50, 3)

# %%
tf.reset_default_graph()
def cnn_model_fn(features , labels , mode):
    input_layers = tf.reshape(features['x'] , [-1 , 50 , 50 ,3])    
    conv1 = tf.layers.conv2d(
        inputs = input_layers , 
        filters = 50 , 
        kernel_size = [7 , 7],
        padding = 'same',
        activation = tf.nn.relu
        ) 
    
    
    conv2 = tf.layers.conv2d(
        inputs = conv1, 
        filters = 90,
        kernel_size = [3 , 3],
        padding = 'valid',
        activation = tf.nn.relu
        )

        
    conv3 = tf.layers.conv2d(
        inputs = conv2 ,
        filters = 10,
        kernel_size = [5 , 5],
        padding = 'same', 
        activation = tf.nn.relu
        )
    
    pool1 = tf.layers.max_pooling2d(inputs = conv3 , pool_size = [2 , 2] ,
                                    strides = 2 )
    conv4 = tf.layers.conv2d(
        inputs = pool1 ,
        filters = 5,
        kernel_size = [3 , 3],
        padding = 'same', 
        activation = tf.nn.relu
        )

    pool2 = tf.layers.max_pooling2d(inputs = conv4 , pool_size = [2 , 2] ,
                                    strides = 2 , padding = 'same')
    
    pool2_flatten = tf.layers.flatten(pool2)
    fc1 = tf.layers.dense(
        inputs = pool2_flatten,
        units = 2000,
        activation = tf.nn.relu
        )
    fc2 = tf.layers.dense(
        inputs = fc1,
        units = 1000,
        activation = tf.nn.relu
        )
    fc3 = tf.layers.dense(
        inputs = fc2 , 
        units = 500 ,
        activation = tf.nn.relu
        )
    logits = tf.layers.dense(
        inputs = fc3 ,
        units = 2
        )
    
    predictions = {
        'classes': tf.argmax(input = logits , axis = 1),
        'probabilities': tf.nn.softmax(logits , name = 'softmax_tensor')
    }
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode = mode , 
                                          predictions = predictions)
    
    loss = tf.losses.sparse_softmax_cross_entropy(labels = labels , 
                                                 logits = logits)
    
    if mode == tf.estimator.ModeKeys.TRAIN:
        optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.001)
        train_op = optimizer.minimize(loss = loss , 
                                      global_step = tf.train.get_global_step())
        
        return tf.estimator.EstimatorSpec(mode = mode , 
                                            loss = loss , 
                                            train_op = train_op 
                                           )
    eval_metric_op = {'accuracy' : tf.metrics.accuracy(labels = labels ,
                                         predictions =  predictions['classes'])}
    
    return tf.estimator.EstimatorSpec(mode = mode , 
                                      loss = loss , 
                                      eval_metric_ops = eval_metric_op)

# %%
malaria_detector = tf.estimator.Estimator(model_fn = cnn_model_fn , 
                                         model_dir = '/tmp/modelchkpt')
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/modelchkpt', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
tensors_to_log = {'probabilities':'softmax_tensor'}
logging_hook = tf.train.LoggingTensorHook(
    tensors = tensors_to_log , every_n_iter = 50 
    )

# %%
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x = {'x': train_x},
    y = train_y,
    batch_size = 100 , 
    num_epochs = None , 
    shuffle = True
    )
malaria_detector.train(input_fn = train_input_fn , steps = 1 , hooks = [logging_hook])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:65: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:491: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From <ipython-input-25-138a532dc522>:9: conv2d (from tensorflow.python.keras.legacy_tf_layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/legacy_tf_layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From <ipython-input-25-138a532dc522>:31: max_pooling2d (from tensorflow.python.keras.legacy_tf_layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# WARNING:tensorflow:From <ipython-input-25-138a532dc522>:43: flatten (from tensorflow.python.keras.legacy_tf_layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Flatten instead.
# WARNING:tensorflow:From <ipython-input-25-138a532dc522>:47: dense (from tensorflow.python.keras.legacy_tf_layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py:906: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/modelchkpt/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1...
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/modelchkpt/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1...
# INFO:tensorflow:Loss for final step: 0.694306.

# %%
malaria_detector.train(input_fn = train_input_fn , steps = 1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/modelchkpt/model.ckpt-1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1077: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1...
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/modelchkpt/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1...
# INFO:tensorflow:loss = 0.69267166, step = 1
# INFO:tensorflow:global_step/sec: 27.8032
# INFO:tensorflow:loss = 0.6934584, step = 101 (3.599 sec)
# INFO:tensorflow:global_step/sec: 28.0784
# INFO:tensorflow:loss = 0.68568766, step = 201 (3.562 sec)
# INFO:tensorflow:global_step/sec: 28.0172
# INFO:tensorflow:loss = 0.69072396, step = 301 (3.567 sec)
# INFO:tensorflow:global_step/sec: 27.9379
# INFO:tensorflow:loss = 0.68482, step = 401 (3.581 sec)
# INFO:tensorflow:global_step/sec: 27.8936
# INFO:tensorflow:loss = 0.6763674, step = 501 (3.586 sec)
# INFO:tensorflow:global_step/sec: 27.8
# INFO:tensorflow:loss = 0.68668985, step = 601 (3.594 sec)
# INFO:tensorflow:global_step/sec: 27.7246
# INFO:tensorflow:loss = 0.6861436, step = 701 (3.608 sec)
# INFO:tensorflow:global_step/sec: 27.6254
# INFO:tensorflow:loss = 0.67790604, step = 801 (3.620 sec)
# INFO:tensorflow:global_step/sec: 27.6316
# INFO:tensorflow:loss = 0.686185, step = 901 (3.619 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1001...
# INFO:tensorflow:Saving checkpoints for 1001 into /tmp/modelchkpt/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1001...
# INFO:tensorflow:Loss for final step: 0.68120795.

# %%
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x = {'x': eval_x},
    y = eval_y , 
    num_epochs = 1 , 
    shuffle = False
    )
eval_results = malaria_detector.evaluate(input_fn = eval_input_fn)
print(eval_results)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-09-15T22:31:40Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/modelchkpt/model.ckpt-1001
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 1.58630s
# INFO:tensorflow:Finished evaluation at 2020-09-15-22:31:42
# INFO:tensorflow:Saving dict for global step 1001: accuracy = 0.567548, global_step = 1001, loss = 0.6792078
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1001: /tmp/modelchkpt/model.ckpt-1001
# {'accuracy': 0.567548, 'loss': 0.6792078, 'global_step': 1001}

# %%
pred_input_fn = tf.estimator.inputs.numpy_input_fn(
    x = {'x' : test_x},
    y = test_y,
    num_epochs = 1,
    shuffle = False
    )

y_pred = malaria_detector.predict(input_fn = pred_input_fn)
classes = [p['classes'] for p in y_pred]
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/modelchkpt/model.ckpt-1001
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
from sklearn.metrics import confusion_matrix , classification_report , accuracy_score
print('{} \n{} \n{}'.format(confusion_matrix(test_y , classes) , 
                           classification_report(test_y , classes) , 
                           accuracy_score(test_y , classes)))
# Out:
# [[   0 4116]
#  [   0 5530]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      4116
#            1       0.57      1.00      0.73      5530
#
#     accuracy                           0.57      9646
#    macro avg       0.29      0.50      0.36      9646
# weighted avg       0.33      0.57      0.42      9646
#
# 0.5732946298984035
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plt.figure(1 , figsize = (15 , 9))
n = 0 
for i in range(49):
    n += 1 
    r = np.random.randint( 0  , test_x.shape[0] , 1)
    plt.subplot(7 , 7 , n)
    plt.subplots_adjust(hspace = 0.5 , wspace = 0.5)
    plt.imshow(test_x[r[0]])
    plt.title('true {} : pred {}'.format(test_y[r[0]] , classes[r[0]]) )
    plt.xticks([]) , plt.yticks([])

plt.show()
